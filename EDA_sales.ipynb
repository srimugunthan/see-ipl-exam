# %%
import pandas as pd

# %%
df = pd.read_excel("./EA - Data - Group 9.xlsx", sheet_name='Sales Data')

# %%
df.head()
# Out:
#    Year  Quarter  Sales  SalesPromo  AdSpend  RelPrice
# 0  2014        1     92    0.602118      0.0       1.1
# 1  2014        2     99    0.208932      1.8       0.9
# 2  2014        3    115    0.060245      2.8       0.1
# 3  2014        4     85    0.002090      1.3       0.5
# 4  2015        1     88    0.045102      1.4       0.6

# %%
df.shape
# Out:
# (36, 6)

# %%
df.describe()
# Out:
#               Year    Quarter        Sales  SalesPromo    AdSpend   RelPrice
# count    36.000000  36.000000    36.000000   36.000000  36.000000  36.000000
# mean   2018.000000   2.500000   129.472222    0.399153   1.758333   0.866667
# std       2.618615   1.133893   166.745741    0.783047   0.651756   0.322490
# min    2014.000000   1.000000    84.000000    0.002090   0.000000   0.100000
# 25%    2016.000000   1.750000    91.250000    0.140183   1.375000   0.700000
# 50%    2018.000000   2.500000   102.500000    0.248131   1.850000   0.900000
# 75%    2020.000000   3.250000   114.000000    0.302017   2.200000   1.025000
# max    2022.000000   4.000000  1100.000000    4.000000   2.800000   1.900000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.index, df['Sales'])

# %%
q = df["Sales"].quantile(0.99)
df_noout = df[df["Sales"] < q]

# %%
df_noout.shape
# Out:
# (35, 6)

# %%
df_noout['Sales'].describe()
# Out:
# count     35.000000
# mean     101.742857
# std       11.257267
# min       84.000000
# 25%       90.500000
# 50%      102.000000
# 75%      113.500000
# max      116.000000
# Name: Sales, dtype: float64

# %%
plt.scatter(df_noout.index, df_noout['Sales'])

# %%
df_noout.plot(x='AdSpend', y='Sales', marker='.')
# Out:
# <Axes: xlabel='AdSpend'>

# %%
plt.scatter(df_noout.Quarter, df_noout['Sales'])
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

# %%
results1 = DataFrame({ 'AdSpend': df_noout['AdSpend'].values, 'Sales': df_noout["Sales"].values})

results1.plot()
plt.legend()
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
plt.scatter(df_noout.AdSpend, df_noout['Sales'])
plt.xlabel("AdSpend")
plt.ylabel("Sales")
plt.show()

# %%
results1 = DataFrame({ 'SalesPromo': df_noout['SalesPromo'].values, 'Sales': df_noout["Sales"].values})

results1.plot()
plt.legend()
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
plt.scatter(df_noout.SalesPromo, df_noout['Sales'])
plt.xlabel("SalesPromo")
plt.ylabel("Sales")
plt.show()

# %%
results1 = DataFrame({ 'RelPrice': df_noout['RelPrice'].values, 'Sales': df_noout["Sales"].values})

results1.plot()
plt.legend()
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
plt.scatter(df_noout.RelPrice, df_noout['Sales'])
plt.xlabel("RelPrice")
plt.ylabel("Sales")
plt.show()
